# %%
import pandas as pd
from sqlalchemy import create_engine
import pymongo
from flask import Flask
import json
import psycopg2
import sys

# %%
popular_breed_data = "C:/Users/jmarshall.000/Desktop/nu-chi-data-pt-04-2021-u-c/ETL-Project/Resources/AKC_Popular_Breeds_2013-2016.csv"
breed_data = "C:/Users/jmarshall.000/Desktop/nu-chi-data-pt-04-2021-u-c/ETL-Project/Resources/dog breeds_enriched_20210503.csv"
breed_data_df = pd.read_csv(breed_data)
popular_breed_data_df = pd.read_csv(popular_breed_data)

breed_data_df.dropna()
breed_data_df.head()
# Out:
#               Breed Breed Group AKC  \
# 0     Affenpinscher       Toy Group
# 1      Afghan Hound     Hound Group
# 2              Aidi  Not Recognized
# 3  Airedale Terrier   Terrier Group
# 4        Akbash Dog  Not Recognized
#
#                                    Breed Group CKC      Breed Group UKC  \
# 0               Group 5: Pinschers and Schnauzers        Companion Dog
# 1                      Group 8: Sighthound Breeds   Sighthound & Pariah
# 2                                   Not Recognized         Guardian Dog
# 3                         Group 6: Terrier Breeds               Terrier
# 4  Group 9: Large Guardian Pastoral/Mountain Dogs          Guardian Dog
#
#                            CKC Subgroup  height_low_inches  \
# 0  5-B: Small Pinschers and Schnauzers                 9.0
# 1          8-B: Long Haired Sighthounds               25.0
# 2                        Not Recognized               20.0
# 3                   6-A: Large Terriers               22.0
# ...

# %%
popular_breed_data_df.dropna()
popular_breed_data_df.head()
# Out:
#                  Breed  2016 Rank  2015 Rank  2014 Rank  2013 Rank
# 0   Labrador Retriever          1        1.0        1.0        1.0
# 1  German Shepherd Dog          2        2.0        2.0        2.0
# 2    Golden Retriever           3        3.0        3.0        3.0
# 3              Bulldog          4        4.0        4.0        5.0
# 4               Beagle          5        5.0        5.0        4.0

# %%
breed_data_df.columns
# Out:
# Index(['Breed', 'Breed Group AKC', 'Breed Group CKC', 'Breed Group UKC',
#        'CKC Subgroup', 'height_low_inches', 'height_high_inches',
#        'average height', 'weight_low_lbs', 'weight_high_lbs', 'average weight',
#        'Lifespan Low', 'Lifespan High', 'average lifespan'],
#       dtype='object')

# %%
popular_breed_data_df.columns
# Out:
# Index(['Breed', '2016 Rank', '2015 Rank', '2014 Rank', '2013 Rank'], dtype='object')

# %%
merged_df = pd.merge(breed_data_df, popular_breed_data_df, how ='outer', on='Breed')
merged_df.head()
# Out:
#               Breed Breed Group AKC  \
# 0     Affenpinscher       Toy Group
# 1      Afghan Hound     Hound Group
# 2              Aidi  Not Recognized
# 3  Airedale Terrier   Terrier Group
# 4        Akbash Dog  Not Recognized
#
#                                    Breed Group CKC      Breed Group UKC  \
# 0               Group 5: Pinschers and Schnauzers        Companion Dog
# 1                      Group 8: Sighthound Breeds   Sighthound & Pariah
# 2                                   Not Recognized         Guardian Dog
# 3                         Group 6: Terrier Breeds               Terrier
# 4  Group 9: Large Guardian Pastoral/Mountain Dogs          Guardian Dog
#
#                            CKC Subgroup  height_low_inches  \
# 0  5-B: Small Pinschers and Schnauzers                 9.0
# 1          8-B: Long Haired Sighthounds               25.0
# 2                        Not Recognized               20.0
# 3                   6-A: Large Terriers               22.0
# ...

# %%
merged_df.count()
# Out:
# Breed                 259
# Breed Group AKC       195
# Breed Group CKC       195
# Breed Group UKC       195
# CKC Subgroup          194
# height_low_inches     195
# height_high_inches    195
# average height        195
# weight_low_lbs        195
# weight_high_lbs       195
# average weight        195
# Lifespan Low          194
# Lifespan High         194
# average lifespan      195
# 2016 Rank             189
# 2015 Rank             184
# 2014 Rank             184
# 2013 Rank             177
# dtype: int64

# %%
clean_merged_df = merged_df.drop_duplicates(subset="Breed")
clean_merged_df.head()
# Out:
#               Breed Breed Group AKC  \
# 0     Affenpinscher       Toy Group
# 1      Afghan Hound     Hound Group
# 2              Aidi  Not Recognized
# 3  Airedale Terrier   Terrier Group
# 4        Akbash Dog  Not Recognized
#
#                                    Breed Group CKC      Breed Group UKC  \
# 0               Group 5: Pinschers and Schnauzers        Companion Dog
# 1                      Group 8: Sighthound Breeds   Sighthound & Pariah
# 2                                   Not Recognized         Guardian Dog
# 3                         Group 6: Terrier Breeds               Terrier
# 4  Group 9: Large Guardian Pastoral/Mountain Dogs          Guardian Dog
#
#                            CKC Subgroup  height_low_inches  \
# 0  5-B: Small Pinschers and Schnauzers                 9.0
# 1          8-B: Long Haired Sighthounds               25.0
# 2                        Not Recognized               20.0
# 3                   6-A: Large Terriers               22.0
# ...

# %%
clean_merged_df.count()
# Out:
# Breed                 259
# Breed Group AKC       195
# Breed Group CKC       195
# Breed Group UKC       195
# CKC Subgroup          194
# height_low_inches     195
# height_high_inches    195
# average height        195
# weight_low_lbs        195
# weight_high_lbs       195
# average weight        195
# Lifespan Low          194
# Lifespan High         194
# average lifespan      195
# 2016 Rank             189
# 2015 Rank             184
# 2014 Rank             184
# 2013 Rank             177
# dtype: int64

# %%
clean_merged_df['Average Rank'] = clean_merged_df[['2016 Rank', '2015 Rank','2014 Rank','2013 Rank']].mean(axis=1)
clean_merged_df.round(1)
# Out:
#                    Breed Breed Group AKC  \
# 0          Affenpinscher       Toy Group
# 1           Afghan Hound     Hound Group
# 2                   Aidi  Not Recognized
# 3       Airedale Terrier   Terrier Group
# 4             Akbash Dog  Not Recognized
# ..                   ...             ...
# 254        Cesky Terrier             NaN
# 255   Cirnechi dell'Etna             NaN
# 256           Bergamasco             NaN
# 257              Sloughi             NaN
# 258  Norwegian Lundehund             NaN
#
#                                      Breed Group CKC      Breed Group UKC  \
# 0                 Group 5: Pinschers and Schnauzers        Companion Dog
# 1                        Group 8: Sighthound Breeds   Sighthound & Pariah
# 2                                     Not Recognized         Guardian Dog
# 3                           Group 6: Terrier Breeds               Terrier
# 4    Group 9: Large Guardian Pastoral/Mountain Dogs          Guardian Dog
# ...

# %%
clean_merged_df.columns
clean_merged_df.dropna()
# Out:
#                            Breed     Breed Group AKC  \
# 0                  Affenpinscher           Toy Group
# 1                   Afghan Hound         Hound Group
# 5                          Akita       Working Group
# 8               Alaskan Malamute       Working Group
# 12           American Eskimo Dog  Non-Sporting Group
# ..                           ...                 ...
# 187       Welsh Springer Spaniel      Sporting Group
# 188                Welsh Terrier       Terrier Group
# 189  West Highland White Terrier       Terrier Group
# 192             Wire Fox Terrier       Terrier Group
# 194            Yorkshire Terrier           Toy Group
#
#                         Breed Group CKC      Breed Group UKC  \
# 0    Group 5: Pinschers and Schnauzers        Companion Dog
# 1           Group 8: Sighthound Breeds   Sighthound & Pariah
# 5      Group 2: Spitz and Nordic Breeds             Northern
# 8      Group 2: Spitz and Nordic Breeds             Northern
# ...

# %%
#connection_string = "postgres:@localhost:5433/"
#engine = create_engine(f'postgresql://{connection_string}')

# %%
engine = create_engine(f'postgresql+psycopg2://postgres:Belinda@8893@localhost:5432/dog_breeds')

# %%
breed_data_df.to_sql(name='breed', con=engine, if_exists='append', index=False)

# %%
popular_breed_data_df.to_sql(name='popular', con=engine, if_exists='append', index=False)

# %%
clean_merged_df.to_csv('dog_breeds')
